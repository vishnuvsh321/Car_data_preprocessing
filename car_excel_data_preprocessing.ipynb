# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('car.xlsx')

# %%
df.head()
# Out:
#              car    price       body  mileage  engV engType registration  \
# 0           Ford  15500.0  crossover       68   2.5     Gas          yes
# 1  Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 2  Mercedes-Benz  35000.0      other      135   5.5  Petrol          yes
# 3  Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 4  Mercedes-Benz  33000.0      vagon       91   NaN   Other          yes
#
#    year    model  drive
# 0  2010     Kuga   full
# 1  2011  E-Class   rear
# 2  2008   CL 550   rear
# 3  2012    B 180  front
# 4  2013  E-Class    NaN

# %%
df.isnull()
# Out:
#         car  price   body  mileage   engV  engType  registration   year  \
# 0     False  False  False    False  False    False         False  False
# 1     False  False  False    False  False    False         False  False
# 2     False  False  False    False  False    False         False  False
# 3     False  False  False    False  False    False         False  False
# 4     False  False  False    False   True    False         False  False
# ...     ...    ...    ...      ...    ...      ...           ...    ...
# 9571  False  False  False    False  False    False         False  False
# 9572  False  False  False    False  False    False         False  False
# 9573  False  False  False    False  False    False         False  False
# 9574  False  False  False    False  False    False         False  False
# 9575  False  False  False    False  False    False         False  False
#
#       model  drive
# 0     False  False
# 1     False  False
# 2     False  False
# 3     False  False
# ...

# %%
df.iloc[1]
# Out:
# car             Mercedes-Benz
# price                 20500.0
# body                    sedan
# mileage                   173
# engV                      1.8
# engType                   Gas
# registration              yes
# year                     2011
# model                 E-Class
# drive                    rear
# Name: 1, dtype: object

# %%
df.isnull().sum()
# Out:
# car               0
# price             0
# body              0
# mileage           0
# engV            434
# engType           0
# registration      0
# year              0
# model             0
# drive           511
# dtype: int64

# %%
df['engV'].fillna(0, inplace=True)
# Out:
# <ipython-input-7-4362b49e9ddb>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['engV'].fillna(0, inplace=True)

# %%
df.isnull().sum()
# Out:
# car               0
# price             0
# body              0
# mileage           0
# engV              0
# engType           0
# registration      0
# year              0
# model             0
# drive           511
# dtype: int64

# %%
mode=df['drive'].mode()
mode
# Out:
# 0    front
# Name: drive, dtype: object

# %%
df["drive"].value_counts()
# Out:
# drive
# front    5188
# full     2500
# rear     1377
# Name: count, dtype: int64

# %%
mode = df['drive'].mode()[0] # Get the first element which is the mode value
df['drive'].replace(np.nan, mode, inplace=True)

# %%
df.isnull().sum()
# Out:
# car             0
# price           0
# body            0
# mileage         0
# engV            0
# engType         0
# registration    0
# year            0
# model           0
# drive           0
# dtype: int64

# %%
mean = df['engV'].mean()

# %%
df.isnull().sum()
# Out:
# car             0
# price           0
# body            0
# mileage         0
# engV            0
# engType         0
# registration    0
# year            0
# model           0
# drive           0
# dtype: int64

# %%
df.head(10)
# Out:
#              car    price       body  mileage  engV engType registration  \
# 0           Ford  15500.0  crossover       68   2.5     Gas          yes
# 1  Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 2  Mercedes-Benz  35000.0      other      135   5.5  Petrol          yes
# 3  Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 4  Mercedes-Benz  33000.0      vagon       91   0.0   Other          yes
# 5         Nissan  16600.0  crossover       83   2.0  Petrol          yes
# 6          Honda   6500.0      sedan      199   2.0  Petrol          yes
# 7        Renault  10500.0      vagon      185   1.5  Diesel          yes
# 8  Mercedes-Benz  21500.0      sedan      146   1.8     Gas          yes
# 9  Mercedes-Benz  22700.0      sedan      125   2.2  Diesel          yes
#
#    year    model  drive
# 0  2010     Kuga   full
# 1  2011  E-Class   rear
# 2  2008   CL 550   rear
# 3  2012    B 180  front
# 4  2013  E-Class  front
# ...

# %%
df['price'].value_counts().head(10)
# Out:
# price
# 0.0        267
# 8500.0      92
# 6500.0      86
# 7500.0      85
# 10500.0     83
# 3500.0      82
# 5500.0      81
# 11500.0     73
# 9500.0      73
# 12500.0     71
# Name: count, dtype: int64

# %%
df.drop(columns=['price'],axis=0, inplace=True)
df
# Out:
#                 car       body  mileage  engV engType registration  year  \
# 0              Ford  crossover       68   2.5     Gas          yes  2010
# 1     Mercedes-Benz      sedan      173   1.8     Gas          yes  2011
# 2     Mercedes-Benz      other      135   5.5  Petrol          yes  2008
# 3     Mercedes-Benz        van      162   1.8  Diesel          yes  2012
# 4     Mercedes-Benz      vagon       91   0.0   Other          yes  2013
# ...             ...        ...      ...   ...     ...          ...   ...
# 9571        Hyundai  crossover      140   2.0     Gas          yes  2011
# 9572     Volkswagen      vagon      150   1.6  Petrol          yes  1986
# 9573  Mercedes-Benz  crossover      180   3.5  Petrol          yes  2008
# 9574          Lexus      sedan      150   3.5     Gas          yes  2008
# 9575           Audi      other       71   3.6  Petrol          yes  2007
#
#           model  drive
# 0          Kuga   full
# 1       E-Class   rear
# ...

# %%
df.drop_duplicates()
# Out:
#                 car       body  mileage  engV engType registration  year  \
# 0              Ford  crossover       68   2.5     Gas          yes  2010
# 1     Mercedes-Benz      sedan      173   1.8     Gas          yes  2011
# 2     Mercedes-Benz      other      135   5.5  Petrol          yes  2008
# 3     Mercedes-Benz        van      162   1.8  Diesel          yes  2012
# 4     Mercedes-Benz      vagon       91   0.0   Other          yes  2013
# ...             ...        ...      ...   ...     ...          ...   ...
# 9571        Hyundai  crossover      140   2.0     Gas          yes  2011
# 9572     Volkswagen      vagon      150   1.6  Petrol          yes  1986
# 9573  Mercedes-Benz  crossover      180   3.5  Petrol          yes  2008
# 9574          Lexus      sedan      150   3.5     Gas          yes  2008
# 9575           Audi      other       71   3.6  Petrol          yes  2007
#
#           model  drive
# 0          Kuga   full
# 1       E-Class   rear
# ...
